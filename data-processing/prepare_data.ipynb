# %%
# %matplotlib inline
import os
# import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# from azureml.core import Workspace, Dataset
from pandas.plotting import autocorrelation_plot
# from scipy import stats
import holidays
import seaborn as sns

# %% [markdown]
# ### 要討論的問題：
#
# 1. 天氣部分的資料我換算成攝氏還是一百多度?
#
# 2. 資料完全沒缺漏，所以我就直接拉timestamp當做data index了(每15分鐘)
#
# 3. timestamp跟data index的UTC時區我全部改成阿姆斯特丹時區，因為資料提供者說來源是荷蘭小鎮，我把UTC時區轉換成阿姆斯特丹時區對MODEL有沒有影響?
#
# 4. 我的time features打算用國定假日，日常或假日，幾月，季節，星期幾，以上幾個項目來分，有需要增加或刪減的嗎？
#
# 5. 這個是比較大的問題，總共有三張table，我不知道哪張需要哪張不用，就全部做成一張，我覺得這不是問題，但是在做lag feature的時候變成要做太多項，想請問有沒有解決辦法，或者有非做不可的column(例如load_actuals那張)，因為我有圖像化大部份資料之間的關聯性，看不太懂紅色那幾張圖, 數據之間有沒有關聯?
#
# 6. 我看Demo有人用Frourier feature來做time feature(Demo影片約35:35)，但是查不到相關資料，查到都是跟音樂有關的，想請問你們知道這是什麼嗎？
# 7. Date Time Features有沒有要加或要改的部分?
# 8. Train Test資料之後再隨機修改

# %% [markdown]
# ### Merge and clean up tables
#
# 3 tables are merged, if there's a need to adjust the way of merging, please tell me ASAP.

# %%
WORKDIR = os.getcwd()
DATADIR = os.path.join(WORKDIR, 'data/src')
print(WORKDIR)
print(DATADIR)
# Out:
# c:\Users\Demmi\ccclub-advanced-final\data-processing
# c:\Users\Demmi\ccclub-advanced-final\data-processing\data/src

# %%
#convert Timezone to CET Amsterdam(data is from NL)
def convert_tz(tb):
    read_tb = pd.read_csv(os.path.join(DATADIR, f'{tb}.csv'))
    table = read_tb.set_index('data_index_')
    table.index = pd.to_datetime(table.index).tz_convert("Europe/Amsterdam")
    return table

# %%
# Merge tables
load_actuals = convert_tz('load_actuals')
wind_solar_predictions = convert_tz('wind_solar_predictions')
weather = convert_tz('weather')
weather['temperature'] = weather['temperature'].apply(lambda x: 5/9 * (float(x) - 32) )  # Impossible to be 270+ Fahrenheit as degree

# Merge by data index(timestamp)
demand = pd.merge(pd.merge(weather, wind_solar_predictions, on=['data_index_'], how='outer'), load_actuals,on='data_index_',  how='outer')
demand['timestamp'] = demand.index  # set index as timestamp column, easier to process data
demand.head()
# print(demand.index)
# Out:
#                            temperature  solar_ghi  solar_prediction_mw  \
# data_index_
# 2020-01-01 01:00:00+01:00   134.994253        0.0                  0.0
# 2020-01-01 01:15:00+01:00   134.958700        0.0                  0.0
# 2020-01-01 01:30:00+01:00   134.923164        0.0                  0.0
# 2020-01-01 01:45:00+01:00   134.887611        0.0                  0.0
# 2020-01-01 02:00:00+01:00   134.679532        0.0                  0.0
#
#                            wind_prediction_mw  load_actuals_mw  \
# data_index_
# 2020-01-01 01:00:00+01:00           70.865426        95.756328
# 2020-01-01 01:15:00+01:00           69.296785        94.836196
# 2020-01-01 01:30:00+01:00           66.977409        93.798127
# 2020-01-01 01:45:00+01:00           64.305715        92.162902
# 2020-01-01 02:00:00+01:00           61.128262        91.506670
#
#                                           timestamp
# data_index_
# 2020-01-01 01:00:00+01:00 2020-01-01 01:00:00+01:00
# 2020-01-01 01:15:00+01:00 2020-01-01 01:15:00+01:00
# 2020-01-01 01:30:00+01:00 2020-01-01 01:30:00+01:00
# 2020-01-01 01:45:00+01:00 2020-01-01 01:45:00+01:00
# 2020-01-01 02:00:00+01:00 2020-01-01 02:00:00+01:00

# %%
#Check datas from a random week to see if it works
plt_df = demand.loc[(demand.timestamp > '2021-01-01') & (demand.timestamp <= '2021-01-07')]
plt.plot(plt_df['timestamp'], plt_df['load_actuals_mw'])
plt.title('Pytown power demand over one week in July 2017')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Fill gaps and generate time series
# Luckily there is no gap in our data.
# We don't have to seperately create the timestamp index since there's no gap in data.

# %%
min_time = min(demand['timestamp'])
min_time
# Out:
# Timestamp('2020-01-01 01:00:00+0100', tz='Europe/Amsterdam')

# %%
# Range: '2020-01-01 01:00:00+0100'--'2021-06-10 02:00:00+0200'
# tz:'Europe/Amsterdam''
max_time = max(demand['timestamp'])
max_time
# Out:
# Timestamp('2021-06-10 02:00:00+0200', tz='Europe/Amsterdam')

# %%
# dt_idx = pd.date_range(min_time, max_time, freq='15min')  # Generate Time series on every 15 mins
# dt_idx

# %%
# demand.index = demand['timestamp']
# demand = demand.reindex(dt_idx)
# print(demand)

# %%
demand[demand.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [temperature, solar_ghi, solar_prediction_mw, wind_prediction_mw, load_actuals_mw, timestamp]
# Index: []

# %%
demand.isnull().sum()  # Data has already been filled
# Out:
# temperature            0
# solar_ghi              0
# solar_prediction_mw    0
# wind_prediction_mw     0
# load_actuals_mw        0
# timestamp              0
# dtype: int64

# %% [markdown]
# ### Check the distrution of data
# - How many available data's/Number Range
# - Please see the comment below for the quality of the data to make the strategy for the models

# %%
# Nice and normal
plt.hist(demand['load_actuals_mw'].dropna(), bins=100)
plt.title('load_actuals_mw')
plt.show()

# %%
# solar_prediction_mw is relatively High with 0 data(no sun at night)
plt.hist(demand['solar_ghi'].dropna(), bins=10)
plt.title('solar_ghi')
plt.show()

# %%
# solar_prediction_mw is relatively High with 0 data(no sun at night)
plt.hist(demand['solar_prediction_mw'].dropna(), bins=10)
plt.title('solar_prediction_mw')
plt.show()

# %%
plt.hist(demand['wind_prediction_mw'].dropna(), bins=10)
plt.title('wind_prediction_mw')
plt.show()

# %%
plt.hist(demand['temperature'].dropna(), bins=100)
plt.title('temperature')
plt.show()

# %% [markdown]
# ### Randomly pick 1 year from the data to see the graph

# %%
# Before: Need to delete outlier data later
plt_df = demand.copy().loc[(demand['timestamp']>='2020-06-01') & (demand['timestamp']<'2021-06-01'), ]
plt.plot(plt_df['timestamp'], plt_df['load_actuals_mw'], markersize=1)
plt.title('Quarter hour load_actuals_mw in 1 year')
plt.ylabel('load_actuals_mw')
plt.xticks(rotation=45)
plt.show()

# %%
# Boxplot visualization
sns.boxplot(demand.load_actuals_mw)
# Out:
# c:\Users\Demmi\ccclub-advanced-final\venv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='load_actuals_mw'>

# %%
# Box Plot
# https://www.whatissixsigma.net/box-plot-diagram-to-identify-outliers/
demand= demand.copy()

Q1 = demand['load_actuals_mw'].quantile(0.25)
Q3 = demand['load_actuals_mw'].quantile(0.75)
IQR = Q3 - Q1

# Turn outlier into NaN
demand['load_actuals_mw'] = demand['load_actuals_mw'].apply(lambda x: np.nan if (float(x) < (Q1 - 1.5 * IQR)) | (float(x) > (Q3 + 1.5 * IQR)) else x)

# %%
demand.isnull().sum()
# Out:
# temperature             0
# solar_ghi               0
# solar_prediction_mw     0
# wind_prediction_mw      0
# load_actuals_mw        17
# timestamp               0
# dtype: int64

# %%
# After: load_actuals_mw data, Beautiful!
plt_df = demand.copy().loc[(demand['timestamp']>='2020-06-01') & (demand['timestamp']<'2021-06-01'), ]
plt.plot(plt_df['timestamp'], plt_df['load_actuals_mw'], markersize=1)
plt.title('Quarter hour load_actuals_mw in 1 year')
plt.ylabel('load_actuals_mw')
plt.xticks(rotation=45)
plt.show()

# %%
# Seems no problem
plt_df = demand.copy().loc[(demand['timestamp']>='2020-06-01') & (demand['timestamp']<'2021-06-01'), ]
plt.plot(plt_df['timestamp'], plt_df['solar_prediction_mw'], markersize=1)
plt.title('Quarter hour solar_prediction_mw in 2020')
plt.ylabel('solar_prediction_mw')
plt.xticks(rotation=45)
plt.show()

# %%
# Data same trend as the solar_prediction_mw data above
plt_df = demand.copy().loc[(demand['timestamp']>='2020-06-01') & (demand['timestamp']<'2021-06-01'), ]
plt.plot(plt_df['timestamp'], plt_df['solar_ghi'], markersize=1)
plt.title('Quarter hour solar_ghi in 2020')
plt.ylabel('solar_ghi')
plt.xticks(rotation=45)
plt.show()

# %%
plt.plot(demand['temperature'], demand['load_actuals_mw'], 'ro', markersize=1)
plt.title('temperature vs load_actuals_mw')
plt.xlabel('temp')
plt.ylabel('load_actuals')
plt.show()

# %%
# Doesn't relate
plt.plot(demand['load_actuals_mw'], demand['wind_prediction_mw'], 'ro', markersize=1)
plt.title('load_actuals vs wind_prediction_mw')
plt.xlabel('load_actuals')
plt.ylabel('wind_prediction_mw')
plt.show()

# %%
# Doesn't relate
plt.plot(demand['temperature'], demand['wind_prediction_mw'], 'ro', markersize=1)
plt.title('temperature vs wind_prediction_mw')
plt.xlabel('temp')
plt.ylabel('wind_prediction_mw')
plt.show()

# %%
# ???
plt.plot(demand['temperature'], demand['solar_prediction_mw'], 'ro', markersize=1)
plt.title('temperature vs solar_prediction_mw')
plt.xlabel('temp')
plt.ylabel('solar_prediction_mw')
plt.show()

# %%
# ???
plt.plot(demand['temperature'], demand['solar_ghi'], 'ro', markersize=1)
plt.title('temperature vs solar_ghi')
plt.xlabel('temp')
plt.ylabel('solar_ghi')
plt.show()

# %%
# 自我相關（英語：Autocorrelation），也叫序列相關，是一個訊號於其自身在不同時間點的互相關。
# 非正式地來說，它就是兩次觀察之間的相似度對它們之間的時間差的函數。它是找出重複模式（如被噪聲掩蓋的週期訊號），或識別隱含在訊號諧波頻率中消失的基頻的數學工具。
# 它常用於訊號處理中，用來分析函數或一系列值，如時域訊號。
# Data starts from:'2020-01-01 00:00:00+0000'(around Wednesday and crossing new year) 
# --> 100 hours is aound weekend at Amsterdam
# --> 200 hours is aound 9 days since start(aound weekend)
# --> 270 hours is aound 11 days since start(aound weekend)
# --> 380 hours is aound 16 days since start(aound weekend)
# Weekends are in higher demands of eletricity
# tz:'UTC'
autocorrelation_plot(demand['load_actuals_mw'].dropna())
plt.xlim(0,504)  # 3 weeks
plt.title('Auto-correlation of hourly demand over a 3 weeks period')
plt.show()

# %%
autocorrelation_plot(demand['load_actuals_mw'].dropna())
# plt.xlim(0,504)  # 3 weeks
plt.title('Auto-correlation of hourly demand over all period')
plt.show()

# %%
autocorrelation_plot(demand['load_actuals_mw'].dropna())
plt.xlim(0, 1440)  # Winter
plt.title('Auto-correlation of hourly demand over Winter')
plt.show()

# %%
autocorrelation_plot(demand['load_actuals_mw'].dropna())
plt.xlim(1440, 3648)  # Spring
plt.title('Auto-correlation of hourly demand over Spring')
plt.show()

# %%
autocorrelation_plot(demand['load_actuals_mw'].dropna())
plt.xlim(3648, 5856)  # Summer
plt.title('Auto-correlation of hourly demand over Summer')
plt.show()

# %%
# Only for trying out
# demand.describe()
# demand.info()

# %% [markdown]
# ### Features

# %%
# References:
# https://machinelearningmastery.com/basic-feature-engineering-time-series-data-python/
# https://towardsdatascience.com/3-ways-to-extract-features-from-dates-927bd89cd5b9

# %%
demand_features = demand.copy()

# %%
# Time Features 如果需要增加標記欄位麻煩跟我說聲

demand_features['month'] = demand_features.timestamp.dt.month  # 1-Jan 12-Dec
# Winter-1 | Spring-2 | Summer-3 | Autumn-4
demand_features['season'] = demand_features['month'].apply(lambda x: x % 12 // 3 + 1)
# Workday-1 | Holiday or weekend-0
nl_holidays = holidays.NL()
demand_features['workdayornot'] = demand['timestamp'].apply(lambda x: 0 if ((type(nl_holidays.get(x)) == str) or (x.dayofweek == 5) or (x.dayofweek == 6))  else 1)  
demand_features.head()
# Out:
#                            temperature  solar_ghi  solar_prediction_mw  \
# data_index_
# 2020-01-01 01:00:00+01:00   134.994253        0.0                  0.0
# 2020-01-01 01:15:00+01:00   134.958700        0.0                  0.0
# 2020-01-01 01:30:00+01:00   134.923164        0.0                  0.0
# 2020-01-01 01:45:00+01:00   134.887611        0.0                  0.0
# 2020-01-01 02:00:00+01:00   134.679532        0.0                  0.0
#
#                            wind_prediction_mw  load_actuals_mw  \
# data_index_
# 2020-01-01 01:00:00+01:00           70.865426        95.756328
# 2020-01-01 01:15:00+01:00           69.296785        94.836196
# 2020-01-01 01:30:00+01:00           66.977409        93.798127
# 2020-01-01 01:45:00+01:00           64.305715        92.162902
# 2020-01-01 02:00:00+01:00           61.128262        91.506670
#
#                                           timestamp  month  season  \
# data_index_
# 2020-01-01 01:00:00+01:00 2020-01-01 01:00:00+01:00      1       1
# 2020-01-01 01:15:00+01:00 2020-01-01 01:15:00+01:00      1       1
# 2020-01-01 01:30:00+01:00 2020-01-01 01:30:00+01:00      1       1
# 2020-01-01 01:45:00+01:00 2020-01-01 01:45:00+01:00      1       1
# 2020-01-01 02:00:00+01:00 2020-01-01 02:00:00+01:00      1       1
#
#                            workdayornot
# data_index_
# 2020-01-01 01:00:00+01:00             0
# 2020-01-01 01:15:00+01:00             0
# 2020-01-01 01:30:00+01:00             0
# 2020-01-01 01:45:00+01:00             0
# 2020-01-01 02:00:00+01:00             0

# %%
def generate_lagged_features(df, var, max_lag):
    for t in range(1, max_lag+1):
        df[var+'_lag'+str(t)] = df[var].shift(t, freq='15min')

# %%
generate_lagged_features(demand_features, 'temperature', 6)
generate_lagged_features(demand_features, 'load_actuals_mw', 6)
generate_lagged_features(demand_features, 'wind_prediction_mw', 6)
generate_lagged_features(demand_features, 'solar_prediction_mw', 6)

# %%
demand_features.head()
# Out:
#                            temperature  solar_ghi  solar_prediction_mw  \
# data_index_
# 2020-01-01 01:00:00+01:00   134.994253        0.0                  0.0
# 2020-01-01 01:15:00+01:00   134.958700        0.0                  0.0
# 2020-01-01 01:30:00+01:00   134.923164        0.0                  0.0
# 2020-01-01 01:45:00+01:00   134.887611        0.0                  0.0
# 2020-01-01 02:00:00+01:00   134.679532        0.0                  0.0
#
#                            wind_prediction_mw  load_actuals_mw  \
# data_index_
# 2020-01-01 01:00:00+01:00           70.865426        95.756328
# 2020-01-01 01:15:00+01:00           69.296785        94.836196
# 2020-01-01 01:30:00+01:00           66.977409        93.798127
# 2020-01-01 01:45:00+01:00           64.305715        92.162902
# 2020-01-01 02:00:00+01:00           61.128262        91.506670
#
#                                           timestamp  month  season  \
# data_index_
# 2020-01-01 01:00:00+01:00 2020-01-01 01:00:00+01:00      1       1
# 2020-01-01 01:15:00+01:00 2020-01-01 01:15:00+01:00      1       1
# 2020-01-01 01:30:00+01:00 2020-01-01 01:30:00+01:00      1       1
# 2020-01-01 01:45:00+01:00 2020-01-01 01:45:00+01:00      1       1
# 2020-01-01 02:00:00+01:00 2020-01-01 02:00:00+01:00      1       1
#
#                            workdayornot  temperature_lag1  ...  \
# data_index_                                                ...
# 2020-01-01 01:00:00+01:00             0               NaN  ...
# 2020-01-01 01:15:00+01:00             0        134.994253  ...
# 2020-01-01 01:30:00+01:00             0        134.958700  ...
# 2020-01-01 01:45:00+01:00             0        134.923164  ...
# 2020-01-01 02:00:00+01:00             0        134.887611  ...
#
#                            wind_prediction_mw_lag3  wind_prediction_mw_lag4  \
# data_index_
# 2020-01-01 01:00:00+01:00                      NaN                      NaN
# 2020-01-01 01:15:00+01:00                      NaN                      NaN
# 2020-01-01 01:30:00+01:00                      NaN                      NaN
# 2020-01-01 01:45:00+01:00                70.865426                      NaN
# 2020-01-01 02:00:00+01:00                69.296785                70.865426
#
#                            wind_prediction_mw_lag5  wind_prediction_mw_lag6  \
# data_index_
# 2020-01-01 01:00:00+01:00                      NaN                      NaN
# 2020-01-01 01:15:00+01:00                      NaN                      NaN
# 2020-01-01 01:30:00+01:00                      NaN                      NaN
# 2020-01-01 01:45:00+01:00                      NaN                      NaN
# 2020-01-01 02:00:00+01:00                      NaN                      NaN
#
#                            solar_prediction_mw_lag1  solar_prediction_mw_lag2  \
# data_index_
# 2020-01-01 01:00:00+01:00                       NaN                       NaN
# 2020-01-01 01:15:00+01:00                       0.0                       NaN
# 2020-01-01 01:30:00+01:00                       0.0                       0.0
# 2020-01-01 01:45:00+01:00                       0.0                       0.0
# 2020-01-01 02:00:00+01:00                       0.0                       0.0
#
#                            solar_prediction_mw_lag3  solar_prediction_mw_lag4  \
# data_index_
# 2020-01-01 01:00:00+01:00                       NaN                       NaN
# 2020-01-01 01:15:00+01:00                       NaN                       NaN
# 2020-01-01 01:30:00+01:00                       NaN                       NaN
# 2020-01-01 01:45:00+01:00                       0.0                       NaN
# 2020-01-01 02:00:00+01:00                       0.0                       0.0
#
#                            solar_prediction_mw_lag5  solar_prediction_mw_lag6
# data_index_
# 2020-01-01 01:00:00+01:00                       NaN                       NaN
# 2020-01-01 01:15:00+01:00                       NaN                       NaN
# 2020-01-01 01:30:00+01:00                       NaN                       NaN
# 2020-01-01 01:45:00+01:00                       NaN                       NaN
# 2020-01-01 02:00:00+01:00                       NaN                       NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Final data cleaning

# %%
demand_features.isnull().sum()
# Out:
# temperature                  0
# solar_ghi                    0
# solar_prediction_mw          0
# wind_prediction_mw           0
# load_actuals_mw             17
# timestamp                    0
# month                        0
# season                       0
# workdayornot                 0
# temperature_lag1             1
# temperature_lag2             2
# temperature_lag3             3
# temperature_lag4             4
# temperature_lag5             5
# temperature_lag6             6
# load_actuals_mw_lag1        18
# load_actuals_mw_lag2        19
# load_actuals_mw_lag3        20
# load_actuals_mw_lag4        21
# load_actuals_mw_lag5        22
# load_actuals_mw_lag6        23
# wind_prediction_mw_lag1      1
# wind_prediction_mw_lag2      2
# wind_prediction_mw_lag3      3
# wind_prediction_mw_lag4      4
# wind_prediction_mw_lag5      5
# wind_prediction_mw_lag6      6
# solar_prediction_mw_lag1     1
# solar_prediction_mw_lag2     2
# solar_prediction_mw_lag3     3
# solar_prediction_mw_lag4     4
# solar_prediction_mw_lag5     5
# solar_prediction_mw_lag6     6
# dtype: int64

# %% [markdown]
# Count numbers of rows with null values

# %%
demand_features.loc[demand_features.isnull().any(axis=1), ].shape[0]
# Out:
# 47

# %% [markdown]
# This is a very small proportion of the overall dataset so can be safely dropped.

# %%
demand_features.dropna(how='any', inplace=True)

# %%
demand_features.to_csv(os.path.join(WORKDIR, 'data/result', 'data_processed_result.csv'), index=False)

# %% [markdown]
# Train Test Split(將資料分成6份，預計過模型的程序如下連結介紹)
# -               -
# - train train test  xxxxx xxxxx xxxxx (train_1, test_1)
# - ->
# - train train train test  xxxxx xxxxx (train_2, test_2)
# - ->
# - train train train train test  xxxxx (train_3, test_3)
# - ->
# - train train train train train test (train_4, test_4)
#
# - https://community.dataquest.io/t/how-to-split-time-series-data-into-training-and-test-set/4116/2

# %%
categorical_cols = ['month', 'season']
dummy_demand_features = pd.get_dummies(data = demand_features, columns = categorical_cols)
dummy_demand_features
# Out:
#                            temperature  solar_ghi  solar_prediction_mw  \
# data_index_
# 2020-01-01 02:30:00+01:00   134.635111        0.0                  0.0
# 2020-01-01 02:45:00+01:00   134.612901        0.0                  0.0
# 2020-01-01 03:00:00+01:00   134.592539        0.0                  0.0
# 2020-01-01 03:15:00+01:00   134.573992        0.0                  0.0
# 2020-01-01 03:30:00+01:00   134.555461        0.0                  0.0
# ...                                ...        ...                  ...
# 2021-06-10 01:00:00+02:00   142.363807        0.0                  0.0
# 2021-06-10 01:15:00+02:00   142.250298        0.0                  0.0
# 2021-06-10 01:30:00+02:00   142.136807        0.0                  0.0
# 2021-06-10 01:45:00+02:00   142.023298        0.0                  0.0
# 2021-06-10 02:00:00+02:00   142.183482        0.0                  0.0
#
#                            wind_prediction_mw  load_actuals_mw  \
# data_index_
# 2020-01-01 02:30:00+01:00           53.949524        89.609819
# 2020-01-01 02:45:00+01:00           50.516558        88.333277
# 2020-01-01 03:00:00+01:00           47.263374        87.394102
# 2020-01-01 03:15:00+01:00           44.792534        86.625883
# 2020-01-01 03:30:00+01:00           42.263742        86.341967
# ...                                       ...              ...
# 2021-06-10 01:00:00+02:00           51.823736        90.339627
# 2021-06-10 01:15:00+02:00           50.666638        88.413236
# 2021-06-10 01:30:00+02:00           49.584024        87.441277
# 2021-06-10 01:45:00+02:00           48.517445        85.329757
# 2021-06-10 02:00:00+02:00           47.509316        84.122788
#
#                                           timestamp  workdayornot  \
# data_index_
# 2020-01-01 02:30:00+01:00 2020-01-01 02:30:00+01:00             0
# 2020-01-01 02:45:00+01:00 2020-01-01 02:45:00+01:00             0
# 2020-01-01 03:00:00+01:00 2020-01-01 03:00:00+01:00             0
# 2020-01-01 03:15:00+01:00 2020-01-01 03:15:00+01:00             0
# 2020-01-01 03:30:00+01:00 2020-01-01 03:30:00+01:00             0
# ...                                             ...           ...
# 2021-06-10 01:00:00+02:00 2021-06-10 01:00:00+02:00             1
# 2021-06-10 01:15:00+02:00 2021-06-10 01:15:00+02:00             1
# 2021-06-10 01:30:00+02:00 2021-06-10 01:30:00+02:00             1
# 2021-06-10 01:45:00+02:00 2021-06-10 01:45:00+02:00             1
# 2021-06-10 02:00:00+02:00 2021-06-10 02:00:00+02:00             1
#
#                            temperature_lag1  temperature_lag2  \
# data_index_
# 2020-01-01 02:30:00+01:00        134.657322        134.679532
# 2020-01-01 02:45:00+01:00        134.635111        134.657322
# 2020-01-01 03:00:00+01:00        134.612901        134.635111
# 2020-01-01 03:15:00+01:00        134.592539        134.612901
# 2020-01-01 03:30:00+01:00        134.573992        134.592539
# ...                                     ...               ...
# 2021-06-10 01:00:00+02:00        142.470008        142.568936
# 2021-06-10 01:15:00+02:00        142.363807        142.470008
# 2021-06-10 01:30:00+02:00        142.250298        142.363807
# 2021-06-10 01:45:00+02:00        142.136807        142.250298
# 2021-06-10 02:00:00+02:00        142.023298        142.136807
#
#                            temperature_lag3  ...  month_7  month_8  month_9  \
# data_index_                                  ...
# 2020-01-01 02:30:00+01:00        134.887611  ...        0        0        0
# 2020-01-01 02:45:00+01:00        134.679532  ...        0        0        0
# 2020-01-01 03:00:00+01:00        134.657322  ...        0        0        0
# 2020-01-01 03:15:00+01:00        134.635111  ...        0        0        0
# 2020-01-01 03:30:00+01:00        134.612901  ...        0        0        0
# ...                                     ...  ...      ...      ...      ...
# 2021-06-10 01:00:00+02:00        142.667847  ...        0        0        0
# 2021-06-10 01:15:00+02:00        142.568936  ...        0        0        0
# 2021-06-10 01:30:00+02:00        142.470008  ...        0        0        0
# 2021-06-10 01:45:00+02:00        142.363807  ...        0        0        0
# 2021-06-10 02:00:00+02:00        142.250298  ...        0        0        0
#
#                            month_10  month_11  month_12  season_1  season_2  \
# data_index_
# 2020-01-01 02:30:00+01:00         0         0         0         1         0
# 2020-01-01 02:45:00+01:00         0         0         0         1         0
# 2020-01-01 03:00:00+01:00         0         0         0         1         0
# 2020-01-01 03:15:00+01:00         0         0         0         1         0
# 2020-01-01 03:30:00+01:00         0         0         0         1         0
# ...                             ...       ...       ...       ...       ...
# 2021-06-10 01:00:00+02:00         0         0         0         0         0
# 2021-06-10 01:15:00+02:00         0         0         0         0         0
# 2021-06-10 01:30:00+02:00         0         0         0         0         0
# 2021-06-10 01:45:00+02:00         0         0         0         0         0
# 2021-06-10 02:00:00+02:00         0         0         0         0         0
#
#                            season_3  season_4
# data_index_
# 2020-01-01 02:30:00+01:00         0         0
# 2020-01-01 02:45:00+01:00         0         0
# 2020-01-01 03:00:00+01:00         0         0
# 2020-01-01 03:15:00+01:00         0         0
# 2020-01-01 03:30:00+01:00         0         0
# ...                             ...       ...
# 2021-06-10 01:00:00+02:00         1         0
# 2021-06-10 01:15:00+02:00         1         0
# 2021-06-10 01:30:00+02:00         1         0
# 2021-06-10 01:45:00+02:00         1         0
# 2021-06-10 02:00:00+02:00         1         0
#
# [50450 rows x 47 columns]

# %%
def generate_train_test(train_s, train_e, test_s, test_e, batch):
    train, test = dummy_demand_features[dummy_demand_features['timestamp'].between(train_s, train_e)], dummy_demand_features[dummy_demand_features['timestamp'].between(test_s, test_e)]
    train.to_csv(os.path.join(WORKDIR, 'data/train', f'data_train_{batch}.csv'), float_format='%.4f', index=False)
    test.to_csv(os.path.join(WORKDIR, 'data/test', f'data_test_{batch}.csv'), float_format='%.4f', index=False)

# %%
generate_train_test('2020-01-01', '2020-05-31 23:45:00','2020-06-01', '2020-08-31 23:45:00',1)
generate_train_test('2020-01-01', '2020-08-31 23:45:00','2020-09-01', '2020-11-30 23:45:00',2)
generate_train_test('2020-01-01', '2020-11-30 23:45:00','2020-12-01', '2021-02-28 23:45:00',3)
generate_train_test('2020-01-01', '2021-02-28 23:45:00','2021-03-01', '2021-06-10 23:45:00',4)
